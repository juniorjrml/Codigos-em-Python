# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
plt.imshow(training_images[0])
print(training_labels[0])
print(training_images[0])

# %% [markdown]
# Normalizando as imagens(deixando os pixels com os valores normalizados entre 0 e 1)

# %%
training_images  = training_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# <h3>camada de entrada:</h3>
#   Flatten() = recebe lista de mais de 1d e transforma em uma equivalente de 1d
# <h3>camada interna 1(e unica nesse caso):</h3>
# Dense() = camada cheia(full conected)
# 128 neurônios<br>
# activation=tf.nn.relu =  x se x>0 senao 0
# <h3>camada de saida:</h3>
# Dense() = ...<br>
# 10 = neurônios<br>
# activation=tf.nn.softmax = recebe uma lista de valores e seleciona o maior

# %%
camada_entrada = tf.keras.layers.Flatten()
camada_interna01 = tf.keras.layers.Dense(1024, activation=tf.nn.relu)
camada_saida = tf.keras.layers.Dense(10, activation=tf.nn.softmax)

modelo_neural = tf.keras.models.Sequential([camada_entrada, camada_interna01, camada_saida])

# %%
modelo_neural.compile(optimizer = "adam",
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

modelo_neural.fit(training_images, training_labels, epochs=10)

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    try:
      if(logs.get('acc')>0.85):
        print("\nReached 95% accuracy so cancelling training!")
        self.model.stop_training = True
    except:
      pass
callbacks = myCallback()

modelo_neural.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
modelo_neural.fit(training_images, training_labels, epochs=10, callbacks=[callbacks])
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.4701 - accuracy: 0.8311
# Epoch 2/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3579 - accuracy: 0.8683
# Epoch 3/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3212 - accuracy: 0.8821
# Epoch 4/10
# 1426/1875 [=====================>........] - ETA: 3s - loss: 0.2982 - accuracy: 0.8888
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-7afd1f21aecc> in <module>()
#      10
#      11 modelo_neural.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 12 modelo_neural.fit(training_images, training_labels, epochs=10, callbacks=[callbacks])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
# ...

# %%
modelo_neural.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8733
# [0.3492245674133301, 0.8733000159263611]

# %%
classificacao = modelo_neural.predict(test_images)
print(classificacao[0])
# Out:
# [1.32401567e-06 1.01982245e-08 1.86850539e-05 2.94942364e-08
#  3.58911120e-06 1.22779387e-03 1.37017078e-05 1.32518694e-01
#  7.02638181e-06 8.66209209e-01]

# %% [markdown]
# Implementando Callback

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('acc')>0.95):
      print("\nReached 95% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images/255.0
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=5, callbacks=[callbacks])
