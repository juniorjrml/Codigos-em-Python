# %% [markdown]
# Acompanhando o tutorial do Tensorflow<br>
#
# https://codelabs.developers.google.com/codelabs/tensorflow-lab1-helloworld/#0

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# units = quantos neoronios<br >
# input_shape = formato dos dados de entradas na camada

# %%
formato_da_camada = [keras.layers.Dense(units=1,input_shape=[1])]
rede_neural = keras.Sequential(formato_do_neoronio)
